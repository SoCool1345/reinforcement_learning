# %%
import torch
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
import time
from matplotlib import pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3 import PPO, DQN, A2C

from gym.wrappers import GrayScaleObservation

from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
import numpy as np
import os
from stable_baselines3.common.callbacks import BaseCallback

env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)


log_dir = './monitor_log/'
os.makedirs(log_dir, exist_ok=True)

env = Monitor(env, log_dir)

env = GrayScaleObservation(env,keep_dim=True)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env,4,channels_order='last')

# %%
class SaveOnStepCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq, save_path, verbose=1):
        super(SaveOnStepCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = os.path.join(save_path, 'best_model')
        

    def _init_callback(self):
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            self.model.save(os.path.join(self.save_path,'_{}'.format(self.n_calls)))
        
        return True

# %%
learning_rate = 1e-6
n_steps = 2048


tensorboard_log = r'./tensorboard_logs/'
model = PPO("CnnPolicy", env, verbose=1,
            learning_rate=learning_rate,n_steps=n_steps,
            tensorboard_log=tensorboard_log)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# cuda
# True
# 1.12.1+cu116

# %%
save_path=r"./"
callback1=SaveOnStepCallback(check_freq=20000,save_path=save_path)
model.learn(total_timesteps=5000000,callback=callback1,reset_num_timesteps=False)
# Out:
# Logging to ./tensorboard_logs/PPO_4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.41e+04 |
# |    ep_rew_mean     | 527      |
# | time/              |          |
# |    fps             | 237      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 57344    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+04    |
# |    ep_rew_mean          | 527         |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 2           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.102393456 |
# |    clip_fraction        | 0.556       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.483       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.3         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.005      |
# |    value_loss           | 4.24        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.41e+04   |
# |    ep_rew_mean          | 527        |
# | time/                   |            |
# |    fps                  | 101        |
# |    iterations           | 3          |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.06305031 |
# |    clip_fraction        | 0.366      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.7       |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.249      |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.008     |
# |    value_loss           | 0.861      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+04    |
# |    ep_rew_mean          | 527         |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 4           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.022330638 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0848      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 0.315       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15e+04    |
# |    ep_rew_mean          | 511         |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 5           |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.027081564 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.00185    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0266     |
# |    value_loss           | 0.13        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.15e+04   |
# |    ep_rew_mean          | 511        |
# | time/                   |            |
# |    fps                  | 88         |
# |    iterations           | 6          |
# |    time_elapsed         | 138        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.08569835 |
# |    clip_fraction        | 0.468      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.5       |
# |    explained_variance   | 0.59       |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.369      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.00562    |
# |    value_loss           | 4.28       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15e+04    |
# |    ep_rew_mean          | 511         |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 7           |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.108226076 |
# |    clip_fraction        | 0.514       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0828     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0704     |
# |    value_loss           | 0.334       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.15e+04   |
# |    ep_rew_mean          | 511        |
# | time/                   |            |
# |    fps                  | 85         |
# |    iterations           | 8          |
# |    time_elapsed         | 190        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.10139394 |
# |    clip_fraction        | 0.548      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | 0.216      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0796    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0676    |
# |    value_loss           | 0.192      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.22e+04   |
# |    ep_rew_mean          | 603        |
# | time/                   |            |
# |    fps                  | 84         |
# |    iterations           | 9          |
# |    time_elapsed         | 217        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.13154683 |
# |    clip_fraction        | 0.593      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.49      |
# |    explained_variance   | 0.0872     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.108     |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0881    |
# |    value_loss           | 0.103      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.22e+04  |
# |    ep_rew_mean          | 603       |
# | time/                   |           |
# |    fps                  | 82        |
# |    iterations           | 10        |
# |    time_elapsed         | 246       |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.1849989 |
# |    clip_fraction        | 0.551     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.919    |
# |    explained_variance   | 0.533     |
# |    learning_rate        | 0.001     |
# |    loss                 | 20.8      |
# |    n_updates            | 350       |
# |    policy_gradient_loss | 0.0331    |
# |    value_loss           | 53.6      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.22e+04   |
# |    ep_rew_mean          | 603        |
# | time/                   |            |
# |    fps                  | 82         |
# |    iterations           | 11         |
# |    time_elapsed         | 273        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.16032872 |
# |    clip_fraction        | 0.505      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | 0.698      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.422      |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.0155     |
# |    value_loss           | 11.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.22e+04   |
# |    ep_rew_mean          | 603        |
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 12         |
# |    time_elapsed         | 299        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.09591928 |
# |    clip_fraction        | 0.527      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.46      |
# |    explained_variance   | 0.791      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0806    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0456    |
# |    value_loss           | 0.184      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.17e+04   |
# |    ep_rew_mean          | 624        |
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 13         |
# |    time_elapsed         | 326        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.14318451 |
# |    clip_fraction        | 0.59       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.4       |
# |    explained_variance   | 0.573      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.114     |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0866    |
# |    value_loss           | 0.144      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.17e+04   |
# |    ep_rew_mean          | 624        |
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 14         |
# |    time_elapsed         | 352        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.08430012 |
# |    clip_fraction        | 0.492      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.817      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.09       |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.0208     |
# |    value_loss           | 6.1        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.17e+04   |
# |    ep_rew_mean          | 624        |
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 15         |
# |    time_elapsed         | 378        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.19187005 |
# |    clip_fraction        | 0.253      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.452     |
# |    explained_variance   | 0.744      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.452      |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.0275     |
# |    value_loss           | 2.43       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.17e+04   |
# |    ep_rew_mean          | 624        |
# | time/                   |            |
# |    fps                  | 80         |
# |    iterations           | 16         |
# |    time_elapsed         | 407        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.09984817 |
# |    clip_fraction        | 0.515      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.576      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.677      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | 0.0114     |
# |    value_loss           | 3.21       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+04    |
# |    ep_rew_mean          | 624         |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 17          |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.112793215 |
# |    clip_fraction        | 0.578       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.326       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0796     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0647     |
# |    value_loss           | 0.112       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.04e+03    |
# |    ep_rew_mean          | 669         |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 18          |
# |    time_elapsed         | 461         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.106816456 |
# |    clip_fraction        | 0.5         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.001       |
# |    loss                 | 8.04        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.0137      |
# |    value_loss           | 18.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.04e+03    |
# |    ep_rew_mean          | 669         |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 19          |
# |    time_elapsed         | 487         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.022933736 |
# |    clip_fraction        | 0.033       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0814     |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.001       |
# |    loss                 | 54.4        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00358     |
# |    value_loss           | 151         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.04e+03   |
# |    ep_rew_mean          | 669        |
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 20         |
# |    time_elapsed         | 514        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.22074708 |
# |    clip_fraction        | 0.42       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.852     |
# |    explained_variance   | 0.782      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.2        |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0126    |
# |    value_loss           | 8.25       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.04e+03   |
# |    ep_rew_mean          | 669        |
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 21         |
# |    time_elapsed         | 539        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.08711693 |
# |    clip_fraction        | 0.44       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.163      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0165    |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0439    |
# |    value_loss           | 0.0963     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.13e+03   |
# |    ep_rew_mean          | 665        |
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 22         |
# |    time_elapsed         | 565        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.16271532 |
# |    clip_fraction        | 0.504      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.15      |
# |    explained_variance   | 0.458      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0752    |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0728    |
# |    value_loss           | 0.0701     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.13e+03   |
# |    ep_rew_mean          | 665        |
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 23         |
# |    time_elapsed         | 590        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.27279994 |
# |    clip_fraction        | 0.462      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.772     |
# |    explained_variance   | 0.885      |
# |    learning_rate        | 0.001      |
# |    loss                 | 5.18       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.033      |
# |    value_loss           | 27.3       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.13e+03   |
# |    ep_rew_mean          | 665        |
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 24         |
# |    time_elapsed         | 616        |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.18395735 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.199     |
# |    explained_variance   | 0.691      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.114      |
# |    n_updates            | 490        |
# |    policy_gradient_loss | 0.0125     |
# |    value_loss           | 0.633      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.13e+03   |
# |    ep_rew_mean          | 665        |
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 25         |
# |    time_elapsed         | 641        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.07048043 |
# |    clip_fraction        | 0.407      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.521      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.251      |
# |    n_updates            | 500        |
# |    policy_gradient_loss | 0.00726    |
# |    value_loss           | 1.94       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.78e+03   |
# |    ep_rew_mean          | 666        |
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 26         |
# |    time_elapsed         | 667        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.15079531 |
# |    clip_fraction        | 0.521      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.451      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.116     |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0753    |
# |    value_loss           | 0.0616     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.49e+03    |
# |    ep_rew_mean          | 677         |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 27          |
# |    time_elapsed         | 693         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.113826826 |
# |    clip_fraction        | 0.463       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.769      |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.001       |
# |    loss                 | 8.6         |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.0451      |
# |    value_loss           | 39.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.49e+03   |
# |    ep_rew_mean          | 677        |
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 28         |
# |    time_elapsed         | 719        |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.04045035 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.127     |
# |    explained_variance   | 0.839      |
# |    learning_rate        | 0.001      |
# |    loss                 | 19.9       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.0102     |
# |    value_loss           | 135        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.49e+03    |
# |    ep_rew_mean          | 677         |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 29          |
# |    time_elapsed         | 749         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.089781605 |
# |    clip_fraction        | 0.0122      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00631    |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.183       |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.00314     |
# |    value_loss           | 0.879       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.49e+03   |
# |    ep_rew_mean          | 677        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 30         |
# |    time_elapsed         | 778        |
# |    total_timesteps      | 116736     |
# | train/                  |            |
# |    approx_kl            | 0.26828754 |
# |    clip_fraction        | 0.286      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.234     |
# |    explained_variance   | 0.817      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.00576    |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.0477    |
# |    value_loss           | 0.44       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.64e+03   |
# |    ep_rew_mean          | 661        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 31         |
# |    time_elapsed         | 808        |
# |    total_timesteps      | 118784     |
# | train/                  |            |
# |    approx_kl            | 0.30416536 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.34      |
# |    explained_variance   | 0.38       |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.712      |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.00623   |
# |    value_loss           | 15         |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.64e+03   |
# |    ep_rew_mean          | 661        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 32         |
# |    time_elapsed         | 838        |
# |    total_timesteps      | 120832     |
# | train/                  |            |
# |    approx_kl            | 0.39794815 |
# |    clip_fraction        | 0.463      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.84      |
# |    explained_variance   | 0.805      |
# |    learning_rate        | 0.001      |
# |    loss                 | 2.22       |
# |    n_updates            | 570        |
# |    policy_gradient_loss | 0.0355     |
# |    value_loss           | 20.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.64e+03   |
# |    ep_rew_mean          | 661        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 33         |
# |    time_elapsed         | 864        |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.69169474 |
# |    clip_fraction        | 0.494      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.427     |
# |    explained_variance   | 0.402      |
# |    learning_rate        | 0.001      |
# |    loss                 | 2.58       |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0103    |
# |    value_loss           | 35         |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.64e+03  |
# |    ep_rew_mean          | 661       |
# | time/                   |           |
# |    fps                  | 78        |
# |    iterations           | 34        |
# |    time_elapsed         | 889       |
# |    total_timesteps      | 124928    |
# | train/                  |           |
# |    approx_kl            | 0.2663554 |
# |    clip_fraction        | 0.406     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.59     |
# |    explained_variance   | 0.55      |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.23      |
# |    n_updates            | 590       |
# |    policy_gradient_loss | 0.000781  |
# |    value_loss           | 9.17      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.77e+03   |
# |    ep_rew_mean          | 665        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 35         |
# |    time_elapsed         | 916        |
# |    total_timesteps      | 126976     |
# | train/                  |            |
# |    approx_kl            | 0.29215246 |
# |    clip_fraction        | 0.502      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.824     |
# |    explained_variance   | 0.439      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0542     |
# |    n_updates            | 600        |
# |    policy_gradient_loss | -0.0214    |
# |    value_loss           | 1.21       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.61e+03   |
# |    ep_rew_mean          | 674        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 36         |
# |    time_elapsed         | 942        |
# |    total_timesteps      | 129024     |
# | train/                  |            |
# |    approx_kl            | 0.23870882 |
# |    clip_fraction        | 0.463      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.813     |
# |    explained_variance   | 0.833      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.227      |
# |    n_updates            | 610        |
# |    policy_gradient_loss | 0.0308     |
# |    value_loss           | 6.87       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.02e+03   |
# |    ep_rew_mean          | 668        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 37         |
# |    time_elapsed         | 967        |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.46674594 |
# |    clip_fraction        | 0.505      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.544     |
# |    explained_variance   | 0.795      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.04       |
# |    n_updates            | 620        |
# |    policy_gradient_loss | 0.0328     |
# |    value_loss           | 23.1       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 4.44e+03  |
# |    ep_rew_mean          | 657       |
# | time/                   |           |
# |    fps                  | 78        |
# |    iterations           | 38        |
# |    time_elapsed         | 993       |
# |    total_timesteps      | 133120    |
# | train/                  |           |
# |    approx_kl            | 0.1363351 |
# |    clip_fraction        | 0.236     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.339    |
# |    explained_variance   | 0.822     |
# |    learning_rate        | 0.001     |
# |    loss                 | 18        |
# |    n_updates            | 630       |
# |    policy_gradient_loss | 0.00845   |
# |    value_loss           | 77.3      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.44e+03   |
# |    ep_rew_mean          | 657        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 39         |
# |    time_elapsed         | 1018       |
# |    total_timesteps      | 135168     |
# | train/                  |            |
# |    approx_kl            | 0.18877262 |
# |    clip_fraction        | 0.321      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.425     |
# |    explained_variance   | 0.755      |
# |    learning_rate        | 0.001      |
# |    loss                 | 14.4       |
# |    n_updates            | 640        |
# |    policy_gradient_loss | 0.0119     |
# |    value_loss           | 64.9       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.26e+03   |
# |    ep_rew_mean          | 664        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 40         |
# |    time_elapsed         | 1046       |
# |    total_timesteps      | 137216     |
# | train/                  |            |
# |    approx_kl            | 0.39785692 |
# |    clip_fraction        | 0.5        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.618     |
# |    explained_variance   | 0.823      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.955      |
# |    n_updates            | 650        |
# |    policy_gradient_loss | 0.0182     |
# |    value_loss           | 13.9       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 4.09e+03  |
# |    ep_rew_mean          | 678       |
# | time/                   |           |
# |    fps                  | 78        |
# |    iterations           | 41        |
# |    time_elapsed         | 1071      |
# |    total_timesteps      | 139264    |
# | train/                  |           |
# |    approx_kl            | 0.5586408 |
# |    clip_fraction        | 0.439     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.448    |
# |    explained_variance   | 0.855     |
# |    learning_rate        | 0.001     |
# |    loss                 | 4.72      |
# |    n_updates            | 660       |
# |    policy_gradient_loss | 0.0503    |
# |    value_loss           | 34.4      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.01e+03   |
# |    ep_rew_mean          | 688        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 42         |
# |    time_elapsed         | 1097       |
# |    total_timesteps      | 141312     |
# | train/                  |            |
# |    approx_kl            | 0.28233385 |
# |    clip_fraction        | 0.284      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.361     |
# |    explained_variance   | 0.881      |
# |    learning_rate        | 0.001      |
# |    loss                 | 54.3       |
# |    n_updates            | 670        |
# |    policy_gradient_loss | 0.0263     |
# |    value_loss           | 59.4       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.87e+03  |
# |    ep_rew_mean          | 708       |
# | time/                   |           |
# |    fps                  | 78        |
# |    iterations           | 43        |
# |    time_elapsed         | 1122      |
# |    total_timesteps      | 143360    |
# | train/                  |           |
# |    approx_kl            | 0.1908454 |
# |    clip_fraction        | 0.346     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.519    |
# |    explained_variance   | 0.902     |
# |    learning_rate        | 0.001     |
# |    loss                 | 5.79      |
# |    n_updates            | 680       |
# |    policy_gradient_loss | 0.0185    |
# |    value_loss           | 24.5      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.82e+03   |
# |    ep_rew_mean          | 716        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 44         |
# |    time_elapsed         | 1148       |
# |    total_timesteps      | 145408     |
# | train/                  |            |
# |    approx_kl            | 0.12847982 |
# |    clip_fraction        | 0.264      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.399     |
# |    explained_variance   | 0.932      |
# |    learning_rate        | 0.001      |
# |    loss                 | 7.33       |
# |    n_updates            | 690        |
# |    policy_gradient_loss | 0.00398    |
# |    value_loss           | 52.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.5e+03    |
# |    ep_rew_mean          | 712        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 45         |
# |    time_elapsed         | 1174       |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.28698146 |
# |    clip_fraction        | 0.394      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.432     |
# |    explained_variance   | 0.862      |
# |    learning_rate        | 0.001      |
# |    loss                 | 4.11       |
# |    n_updates            | 700        |
# |    policy_gradient_loss | 0.0176     |
# |    value_loss           | 23.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.43e+03    |
# |    ep_rew_mean          | 711         |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 46          |
# |    time_elapsed         | 1200        |
# |    total_timesteps      | 149504      |
# | train/                  |             |
# |    approx_kl            | 0.022877418 |
# |    clip_fraction        | 0.0915      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.105      |
# |    explained_variance   | 0.53        |
# |    learning_rate        | 0.001       |
# |    loss                 | 105         |
# |    n_updates            | 710         |
# |    policy_gradient_loss | 0.00694     |
# |    value_loss           | 165         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.43e+03   |
# |    ep_rew_mean          | 711        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 47         |
# |    time_elapsed         | 1225       |
# |    total_timesteps      | 151552     |
# | train/                  |            |
# |    approx_kl            | 0.84820867 |
# |    clip_fraction        | 0.391      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.359     |
# |    explained_variance   | 0.865      |
# |    learning_rate        | 0.001      |
# |    loss                 | 9.04       |
# |    n_updates            | 720        |
# |    policy_gradient_loss | 0.031      |
# |    value_loss           | 54.8       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.43e+03   |
# |    ep_rew_mean          | 711        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 48         |
# |    time_elapsed         | 1251       |
# |    total_timesteps      | 153600     |
# | train/                  |            |
# |    approx_kl            | 0.43826395 |
# |    clip_fraction        | 0.315      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.301     |
# |    explained_variance   | 0.786      |
# |    learning_rate        | 0.001      |
# |    loss                 | 2.86       |
# |    n_updates            | 730        |
# |    policy_gradient_loss | 0.0219     |
# |    value_loss           | 14.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.53e+03   |
# |    ep_rew_mean          | 735        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 49         |
# |    time_elapsed         | 1278       |
# |    total_timesteps      | 155648     |
# | train/                  |            |
# |    approx_kl            | 0.52721834 |
# |    clip_fraction        | 0.519      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.491     |
# |    explained_variance   | 0.486      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.837      |
# |    n_updates            | 740        |
# |    policy_gradient_loss | 0.0261     |
# |    value_loss           | 10.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.53e+03   |
# |    ep_rew_mean          | 735        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 50         |
# |    time_elapsed         | 1303       |
# |    total_timesteps      | 157696     |
# | train/                  |            |
# |    approx_kl            | 0.32827812 |
# |    clip_fraction        | 0.412      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.41      |
# |    explained_variance   | 0.623      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.03       |
# |    n_updates            | 750        |
# |    policy_gradient_loss | 0.0192     |
# |    value_loss           | 18.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.53e+03   |
# |    ep_rew_mean          | 735        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 51         |
# |    time_elapsed         | 1329       |
# |    total_timesteps      | 159744     |
# | train/                  |            |
# |    approx_kl            | 0.32950008 |
# |    clip_fraction        | 0.435      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.516     |
# |    explained_variance   | 0.876      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.378      |
# |    n_updates            | 760        |
# |    policy_gradient_loss | 0.0136     |
# |    value_loss           | 9.47       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.51e+03  |
# |    ep_rew_mean          | 771       |
# | time/                   |           |
# |    fps                  | 78        |
# |    iterations           | 52        |
# |    time_elapsed         | 1355      |
# |    total_timesteps      | 161792    |
# | train/                  |           |
# |    approx_kl            | 1.0270543 |
# |    clip_fraction        | 0.52      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.501    |
# |    explained_variance   | 0.83      |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.467     |
# |    n_updates            | 770       |
# |    policy_gradient_loss | 0.0119    |
# |    value_loss           | 8.35      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.21e+03   |
# |    ep_rew_mean          | 762        |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 53         |
# |    time_elapsed         | 1381       |
# |    total_timesteps      | 163840     |
# | train/                  |            |
# |    approx_kl            | 0.22919978 |
# |    clip_fraction        | 0.275      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.263     |
# |    explained_variance   | 0.888      |
# |    learning_rate        | 0.001      |
# |    loss                 | 9.61       |
# |    n_updates            | 780        |
# |    policy_gradient_loss | 0.0541     |
# |    value_loss           | 56         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.01e+03    |
# |    ep_rew_mean          | 756         |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 54          |
# |    time_elapsed         | 1407        |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.022138193 |
# |    clip_fraction        | 0.0283      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0281     |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.001       |
# |    loss                 | 47.7        |
# |    n_updates            | 790         |
# |    policy_gradient_loss | 0.0119      |
# |    value_loss           | 167         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.84e+03    |
# |    ep_rew_mean          | 751         |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 55          |
# |    time_elapsed         | 1433        |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.002793538 |
# |    clip_fraction        | 0.0139      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0253     |
# |    explained_variance   | 0.736       |
# |    learning_rate        | 0.001       |
# |    loss                 | 135         |
# |    n_updates            | 800         |
# |    policy_gradient_loss | 0.000237    |
# |    value_loss           | 170         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.66e+03     |
# |    ep_rew_mean          | 745          |
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 56           |
# |    time_elapsed         | 1458         |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0058516217 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0252      |
# |    explained_variance   | 0.768        |
# |    learning_rate        | 0.001        |
# |    loss                 | 28.8         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | 0.0093       |
# |    value_loss           | 203          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# ...
# |    policy_gradient_loss | -7.59e-09     |
# |    value_loss           | 214           |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 481       |
# |    ep_rew_mean          | 680       |
# | time/                   |           |
# |    fps                  | 75        |
# |    iterations           | 1138      |
# |    time_elapsed         | 31037     |
# |    total_timesteps      | 2385920   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.33e-07 |
# |    explained_variance   | 0.776     |
# |    learning_rate        | 0.001     |
# |    loss                 | 89.1      |
# |    n_updates            | 11630     |
# |    policy_gradient_loss | 1.61e-09  |
# |    value_loss           | 195       |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 481           |
# |    ep_rew_mean          | 680           |
# | time/                   |               |
# |    fps                  | 75            |
# |    iterations           | 1139          |
# |    time_elapsed         | 31064         |
# |    total_timesteps      | 2387968       |
# | train/                  |               |
# |    approx_kl            | -2.910383e-10 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.53e-07     |
# |    explained_variance   | 0.785         |
# |    learning_rate        | 0.001         |
# |    loss                 | 67.2          |
# |    n_updates            | 11640         |
# |    policy_gradient_loss | 1.2e-09       |
# |    value_loss           | 191           |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 481       |
# |    ep_rew_mean          | 680       |
# | time/                   |           |
# |    fps                  | 75        |
# |    iterations           | 1140      |
# |    time_elapsed         | 31091     |
# |    total_timesteps      | 2390016   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.8e-07  |
# |    explained_variance   | 0.768     |
# |    learning_rate        | 0.001     |
# |    loss                 | 176       |
# |    n_updates            | 11650     |
# |    policy_gradient_loss | -5.46e-09 |
# |    value_loss           | 200       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 481       |
# |    ep_rew_mean          | 680       |
# | time/                   |           |
# |    fps                  | 75        |
# |    iterations           | 1141      |
# |    time_elapsed         | 31118     |
# |    total_timesteps      | 2392064   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.11e-07 |
# |    explained_variance   | 0.779     |
# |    learning_rate        | 0.001     |
# |    loss                 | 169       |
# |    n_updates            | 11660     |
# |    policy_gradient_loss | -8.77e-09 |
# |    value_loss           | 215       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 481       |
# |    ep_rew_mean          | 680       |
# | time/                   |           |
# |    fps                  | 75        |
# |    iterations           | 1142      |
# |    time_elapsed         | 31145     |
# |    total_timesteps      | 2394112   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.95e-07 |
# |    explained_variance   | 0.778     |
# |    learning_rate        | 0.001     |
# |    loss                 | 61.9      |
# |    n_updates            | 11670     |
# |    policy_gradient_loss | 1.71e-09  |
# |    value_loss           | 196       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 481       |
# |    ep_rew_mean          | 680       |
# | time/                   |           |
# |    fps                  | 75        |
# |    iterations           | 1143      |
# |    time_elapsed         | 31174     |
# |    total_timesteps      | 2396160   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.31e-07 |
# |    explained_variance   | 0.762     |
# |    learning_rate        | 0.001     |
# |    loss                 | 122       |
# |    n_updates            | 11680     |
# |    policy_gradient_loss | -2.52e-09 |
# |    value_loss           | 204       |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 481           |
# |    ep_rew_mean          | 680           |
# | time/                   |               |
# |    fps                  | 75            |
# |    iterations           | 1144          |
# |    time_elapsed         | 31201         |
# |    total_timesteps      | 2398208       |
# | train/                  |               |
# |    approx_kl            | -8.731149e-11 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.43e-07     |
# |    explained_variance   | 0.777         |
# |    learning_rate        | 0.001         |
# |    loss                 | 111           |
# |    n_updates            | 11690         |
# |    policy_gradient_loss | -5.53e-10     |
# |    value_loss           | 188           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 481          |
# |    ep_rew_mean          | 680          |
# | time/                   |              |
# |    fps                  | 75           |
# |    iterations           | 1145         |
# |    time_elapsed         | 31228        |
# |    total_timesteps      | 2400256      |
# | train/                  |              |
# |    approx_kl            | 2.910383e-11 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.36e-07    |
# |    explained_variance   | 0.781        |
# |    learning_rate        | 0.001        |
# |    loss                 | 59.4         |
# |    n_updates            | 11700        |
# |    policy_gradient_loss | -7.95e-09    |
# |    value_loss           | 208          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 481           |
# |    ep_rew_mean          | 680           |
# | time/                   |               |
# |    fps                  | 75            |
# |    iterations           | 1146          |
# |    time_elapsed         | 31254         |
# |    total_timesteps      | 2402304       |
# | train/                  |               |
# |    approx_kl            | -5.820766e-11 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.31e-07     |
# |    explained_variance   | 0.777         |
# |    learning_rate        | 0.001         |
# |    loss                 | 65.7          |
# |    n_updates            | 11710         |
# |    policy_gradient_loss | -8.83e-10     |
# |    value_loss           | 191           |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 481       |
# |    ep_rew_mean          | 680       |
# | time/                   |           |
# |    fps                  | 75        |
# |    iterations           | 1147      |
# |    time_elapsed         | 31281     |
# |    total_timesteps      | 2404352   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.01e-07 |
# |    explained_variance   | 0.762     |
# |    learning_rate        | 0.001     |
# |    loss                 | 151       |
# |    n_updates            | 11720     |
# |    policy_gradient_loss | -1.6e-09  |
# |    value_loss           | 203       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 481       |
# |    ep_rew_mean          | 680       |
# | time/                   |           |
# |    fps                  | 75        |
# |    iterations           | 1148      |
# |    time_elapsed         | 31308     |
# |    total_timesteps      | 2406400   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.94e-08 |
# |    explained_variance   | 0.771     |
# |    learning_rate        | 0.001     |
# |    loss                 | 155       |
# |    n_updates            | 11730     |
# |    policy_gradient_loss | -6.74e-10 |
# |    value_loss           | 189       |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 481           |
# |    ep_rew_mean          | 680           |
# | time/                   |               |
# |    fps                  | 75            |
# |    iterations           | 1149          |
# |    time_elapsed         | 31335         |
# |    total_timesteps      | 2408448       |
# | train/                  |               |
# |    approx_kl            | 2.6193447e-10 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.2e-07      |
# |    explained_variance   | 0.774         |
# |    learning_rate        | 0.001         |
# |    loss                 | 86.7          |
# |    n_updates            | 11740         |
# |    policy_gradient_loss | -5.05e-09     |
# |    value_loss           | 211           |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 481       |
# |    ep_rew_mean          | 680       |
# | time/                   |           |
# |    fps                  | 75        |
# |    iterations           | 1150      |
# |    time_elapsed         | 31362     |
# |    total_timesteps      | 2410496   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.12e-07 |
# |    explained_variance   | 0.777     |
# |    learning_rate        | 0.001     |
# |    loss                 | 220       |
# |    n_updates            | 11750     |
# |    policy_gradient_loss | -2.12e-09 |
# |    value_loss           | 196       |
# ---------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 481            |
# |    ep_rew_mean          | 680            |
# | time/                   |                |
# |    fps                  | 75             |
# |    iterations           | 1151           |
# |    time_elapsed         | 31390          |
# |    total_timesteps      | 2412544        |
# | train/                  |                |
# |    approx_kl            | -2.6193447e-10 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.13e-07      |
# |    explained_variance   | 0.76           |
# |    learning_rate        | 0.001          |
# |    loss                 | 119            |
# |    n_updates            | 11760          |
# |    policy_gradient_loss | 3.54e-09       |
# |    value_loss           | 210            |
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 save_path=r"./best_model"
#       2 callback1=SaveOnStepCallback(check_freq=20000,save_path=save_path)
# ----> 3 model.learn(total_timesteps=5000000,callback=callback1,reset_num_timesteps=False)
#
# File c:\users\zhou\pycharmprojects\reinforcement_learning\venv\lib\site-packages\stable_baselines3\ppo\ppo.py:310, in PPO.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     297 def learn(
#     298     self,
#     299     total_timesteps: int,
#    (...)
#     307     reset_num_timesteps: bool = True,
#     308 ) -> "PPO":
# --> 310     return super().learn(
#     311         total_timesteps=total_timesteps,
#     312         callback=callback,
#     313         log_interval=log_interval,
#     314         eval_env=eval_env,
#     315         eval_freq=eval_freq,
#     316         n_eval_episodes=n_eval_episodes,
#     317         tb_log_name=tb_log_name,
#     318         eval_log_path=eval_log_path,
#     319         reset_num_timesteps=reset_num_timesteps,
#     320     )
#
# File c:\users\zhou\pycharmprojects\reinforcement_learning\venv\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:267, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     264         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     265         self.logger.dump(step=self.num_timesteps)
# --> 267     self.train()
#     269 callback.on_training_end()
#     271 return self
#
# File c:\users\zhou\pycharmprojects\reinforcement_learning\venv\lib\site-packages\stable_baselines3\ppo\ppo.py:199, in PPO.train(self)
#     197 approx_kl_divs = []
#     198 # Do a complete pass on the rollout buffer
# --> 199 for rollout_data in self.rollout_buffer.get(self.batch_size):
#     200     actions = rollout_data.actions
#     201     if isinstance(self.action_space, spaces.Discrete):
#     202         # Convert discrete action from float to long
#
# File c:\users\zhou\pycharmprojects\reinforcement_learning\venv\lib\site-packages\stable_baselines3\common\buffers.py:471, in RolloutBuffer.get(self, batch_size)
#     469 start_idx = 0
#     470 while start_idx < self.buffer_size * self.n_envs:
# --> 471     yield self._get_samples(indices[start_idx : start_idx + batch_size])
#     472     start_idx += batch_size
#
# File c:\users\zhou\pycharmprojects\reinforcement_learning\venv\lib\site-packages\stable_baselines3\common\buffers.py:483, in RolloutBuffer._get_samples(self, batch_inds, env)
#     474 def _get_samples(self, batch_inds: np.ndarray, env: Optional[VecNormalize] = None) -> RolloutBufferSamples:
#     475     data = (
#     476         self.observations[batch_inds],
#     477         self.actions[batch_inds],
#    (...)
#     481         self.returns[batch_inds].flatten(),
#     482     )
# --> 483     return RolloutBufferSamples(*tuple(map(self.to_torch, data)))
#
# File c:\users\zhou\pycharmprojects\reinforcement_learning\venv\lib\site-packages\stable_baselines3\common\buffers.py:134, in BaseBuffer.to_torch(self, array, copy)
#     124 """
#     125 Convert a numpy array to a PyTorch tensor.
#     126 Note: it copies the data by default
#    (...)
#     131 :return:
#     132 """
#     133 if copy:
# --> 134     return th.tensor(array).to(self.device)
#     135 return th.as_tensor(array).to(self.device)
#
# KeyboardInterrupt:
